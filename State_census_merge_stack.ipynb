# %%
import pandas as pd
import numpy as np

# %%
state_census = pd.read_csv("st-est00int-01.csv", thousands=',')

state_census_00to19 = pd.read_csv(r"/Users/jasonlim/Desktop/EFGS/Census-master/2019 Population/state-est2010-2019.csv")

# %%
state_census.head()
# Out:
#            State    jul2000    jul2001    jul2002    jul2003    jul2004  \
# 0  United States  282162411  284968955  287625193  290107933  292805298
# 1      Northeast   53666295   53915522   54143915   54334453   54423533
# 2        Midwest   64491431   64776531   65018293   65276954   65532305
# 3          South  100565549  101849575  103150787  104380188  105883977
# 4           West   63439136   64427327   65312198   66116338   66965483
#
#      jul2005    jul2006    jul2007    jul2008    jul2009
# 0  295516599  298379912  301231207  304093966  306771529
# 1   54451230   54522659   54653362   54875926   55133101
# 2   65751872   66028555   66293689   66523935   66748437
# 3  107479771  109076933  110688742  112184930  113548615
# 4   67833726   68751765   69595414   70509175   71341376

# %%
state_census_00to19.head()
# Out:
#    SUMLEV REGION DIVISION  STATE              NAME  ESTIMATESBASE2010  \
# 0      10      0        0      0     United States          308758105
# 1      20      1        0      0  Northeast Region           55318443
# 2      20      2        0      0    Midwest Region           66929725
# 3      20      3        0      0      South Region          114563030
# 4      20      4        0      0       West Region           71946907
#
#    POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# 0        309321666        311556874        313830990        315993715
# 1         55380134         55604223         55775216         55901806
# 2         66974416         67157800         67336743         67560379
# 3        114866680        116006522        117241208        118364400
# 4         72100436         72788329         73477823         74167130
#
#    POPESTIMATE2014  POPESTIMATE2015  POPESTIMATE2016  POPESTIMATE2017  \
# ...

# %%
state_census_00to19.columns
# Out:
# Index(['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'NAME', 'ESTIMATESBASE2010',
#        'POPESTIMATE2010', 'POPESTIMATE2011', 'POPESTIMATE2012',
#        'POPESTIMATE2013', 'POPESTIMATE2014', 'POPESTIMATE2015',
#        'POPESTIMATE2016', 'POPESTIMATE2017', 'POPESTIMATE2018',
#        'POPESTIMATE2019'],
#       dtype='object')

# %%
# Filter only the necessary columns

state_census_00to19= state_census_00to19[['NAME','POPESTIMATE2010', 'POPESTIMATE2011', 'POPESTIMATE2012',
       'POPESTIMATE2013', 'POPESTIMATE2014', 'POPESTIMATE2015',
       'POPESTIMATE2016', 'POPESTIMATE2017', 'POPESTIMATE2018',
       'POPESTIMATE2019']]

# %%
df_comb = state_census.merge(state_census_00to19, left_on='State', right_on='NAME')

# %%
df_comb.head()
# Out:
#            State    jul2000    jul2001    jul2002    jul2003    jul2004  \
# 0  United States  282162411  284968955  287625193  290107933  292805298
# 1        Alabama    4452173    4467634    4480089    4503491    4530729
# 2         Alaska     627963     633714     642337     648414     659286
# 3        Arizona    5160586    5273477    5396255    5510364    5652404
# 4       Arkansas    2678588    2691571    2705927    2724816    2749686
#
#      jul2005    jul2006    jul2007    jul2008  ...  POPESTIMATE2010  \
# 0  295516599  298379912  301231207  304093966  ...        309321666
# 1    4569805    4628981    4672840    4718206  ...          4785437
# 2     666946     675302     680300     687455  ...           713910
# 3    5839077    6029141    6167681    6280362  ...          6407172
# 4    2781097    2821761    2848650    2874554  ...          2921964
#
#   POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  \
# ...

# %%
df_comb.tail()
# Out:
#             State  jul2000  jul2001  jul2002  jul2003  jul2004  jul2005  \
# 48     Washington  5910512  5985722  6052349  6104115  6178645  6257305
# 49  West Virginia  1807021  1801481  1805414  1812295  1816438  1820492
# 50      Wisconsin  5373999  5406835  5445162  5479203  5514026  5546166
# 51        Wyoming   494300   494657   500017   503453   509106   514157
# 52    Puerto Rico  3810605  3818774  3823701  3826095  3826878  3821362
#
#     jul2006  jul2007  jul2008  ...  POPESTIMATE2010 POPESTIMATE2011  \
# 48  6370753  6461587  6562231  ...          6742830         6826627
# 49  1827912  1834052  1840310  ...          1854239         1856301
# 50  5577655  5610775  5640996  ...          5690475         5705288
# 51   522667   534876   546043  ...           564487          567299
# 52  3805214  3782995  3760866  ...          3721525         3678732
#
#     POPESTIMATE2012  POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  \
# ...

# %%
df=df_comb.set_index('State')

# %%
new_df = pd.DataFrame(df.stack())

# %%
new_df = new_df.reset_index()

# %%
new_df.head()
# Out:
#            State  level_1          0
# 0  United States  jul2000  282162411
# 1  United States  jul2001  284968955
# 2  United States  jul2002  287625193
# 3  United States  jul2003  290107933
# 4  United States  jul2004  292805298

# %%
# assign Column name

new_df.columns = ['STATE', 'YEAR', 'POP_TOTAL']

# %%
new_df.head()
# Out:
#            STATE     YEAR  POP_TOTAL
# 0  United States  jul2000  282162411
# 1  United States  jul2001  284968955
# 2  United States  jul2002  287625193
# 3  United States  jul2003  290107933
# 4  United States  jul2004  292805298

# %%
new_df["YEAR"].str[-4:]
# Out:
# 0       2000
# 1       2001
# 2       2002
# 3       2003
# 4       2004
#         ...
# 1108    2015
# 1109    2016
# 1110    2017
# 1111    2018
# 1112    2019
# Name: YEAR, Length: 1113, dtype: object

# %%
# Take out unuseful words from Year
new_df["YEAR"] = new_df["YEAR"].str[-4:]

# %%
new_df.head()
# Out:
#            STATE  YEAR  POP_TOTAL
# 0  United States  2000  282162411
# 1  United States  2001  284968955
# 2  United States  2002  287625193
# 3  United States  2003  290107933
# 4  United States  2004  292805298

# %%
new_df.to_csv("state_00to19.csv", index=False)
# Out:
#                         jul2000    jul2001    jul2002    jul2003    jul2004  \
# State
# Alabama                 4452173    4467634    4480089    4503491    4530729
# Alaska                   627963     633714     642337     648414     659286
# Arizona                 5160586    5273477    5396255    5510364    5652404
# Arkansas                2678588    2691571    2705927    2724816    2749686
# California             33987977   34479458   34871843   35253159   35574576
# Colorado                4326921    4425687    4490406    4528732    4575013
# Connecticut             3411777    3432835    3458749    3484336    3496094
# Delaware                 786373     795699     806169     818003     830803
# District of Columbia     572046     574504     573158     568502     567754
# Florida                16047515   16356966   16689370   17004085   17415318
# Georgia                 8227303    8377038    8508256    8622793    8769252
# ...
